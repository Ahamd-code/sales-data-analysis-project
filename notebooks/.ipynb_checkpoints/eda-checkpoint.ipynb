# %%
import pandas as dp
import matplotlib.pyplot as plt
data = dp.read_csv('../data/raw/superstore.csv', encoding='latin1')
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
# ...

# %%
data.isnull()
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 9989   False     False       False      False      False        False
# 9990   False     False       False      False      False        False
# 9991   False     False       False      False      False        False
# 9992   False     False       False      False      False        False
# 9993   False     False       False      False      False        False
#
#       Customer Name  Segment  Country   City  ...  Postal Code  Region  \
# ...

# %%
data.isnull().count()
# Out:
# Row ID           9994
# Order ID         9994
# Order Date       9994
# Ship Date        9994
# Ship Mode        9994
# Customer ID      9994
# Customer Name    9994
# Segment          9994
# Country          9994
# City             9994
# State            9994
# Postal Code      9994
# Region           9994
# Product ID       9994
# Category         9994
# Sub-Category     9994
# Product Name     9994
# Sales            9994
# Quantity         9994
# Discount         9994
# Profit           9994
# dtype: int64

# %%
len(data)
# Out:
# 9994

# %%
len(data.columns)
# Out:
# 21

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
 data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
# ...

# %%
data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data['Region'] == 'West'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9989    False
# 9990     True
# 9991     True
# 9992     True
# 9993     True
# Name: Region, Length: 9994, dtype: bool

# %%
data[data['Region'] == 'West']
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2          3  CA-2016-138688  6/12/2016  6/16/2016    Second Class
# 5          6  CA-2014-115812   6/9/2014  6/14/2014  Standard Class
# 6          7  CA-2014-115812   6/9/2014  6/14/2014  Standard Class
# 7          8  CA-2014-115812   6/9/2014  6/14/2014  Standard Class
# 8          9  CA-2014-115812   6/9/2014  6/14/2014  Standard Class
# ...      ...             ...        ...        ...             ...
# 9986    9987  CA-2016-125794  9/29/2016  10/3/2016  Standard Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID    Customer Name    Segment        Country         City  ...  \
# 2       DV-13045  Darrin Van Huff  Corporate  United States  Los Angeles  ...
# ...

# %%
data[data['Order ID'] == 'CA-2016-138688']
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 2       3  CA-2016-138688  6/12/2016  6/16/2016  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ... Postal Code  \
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
#
#    Region       Product ID         Category Sub-Category  \
# 2    West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name  Sales  Quantity  \
# 2  Self-Adhesive Address Labels for Typewriters b...  14.62         2
#
#    Discount  Profit
# 2       0.0  6.8714
#
# [1 rows x 21 columns]

# %%
data[data['Postal Code'] == 90008]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 477      478  CA-2016-103891   7/12/2016   7/19/2016  Standard Class
# 565      566  CA-2017-137099   12/7/2017  12/10/2017     First Class
# 1070    1071  CA-2015-144652  11/20/2015  11/26/2015  Standard Class
# 1172    1173  CA-2014-158064   4/21/2014   4/25/2014  Standard Class
# 1336    1337  US-2017-123281    4/2/2017    4/7/2017  Standard Class
# ...      ...             ...         ...         ...             ...
# 9848    9849  CA-2017-169327    9/2/2017    9/4/2017    Second Class
# 9883    9884  CA-2014-112291    4/3/2014    4/8/2014  Standard Class
# 9884    9885  CA-2014-112291    4/3/2014    4/8/2014  Standard Class
# 9885    9886  CA-2014-112291    4/3/2014    4/8/2014  Standard Class
# 9986    9987  CA-2016-125794   9/29/2016   10/3/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country         City  \
# ...

# %%
data[data['Customer Name'] == 'Darrin Van Huff']
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 2976    2977  CA-2017-139773   12/4/2017   12/4/2017        Same Day
# 5298    5299  CA-2016-106656   9/23/2016   9/26/2016     First Class
# 5299    5300  CA-2016-106656   9/23/2016   9/26/2016     First Class
# 5617    5618  CA-2017-125745   6/30/2017    7/4/2017  Standard Class
# 7344    7345  CA-2017-168389  12/11/2017  12/17/2017  Standard Class
# 7345    7346  CA-2017-168389  12/11/2017  12/17/2017  Standard Class
# 7346    7347  CA-2017-168389  12/11/2017  12/17/2017  Standard Class
# 7347    7348  CA-2017-168389  12/11/2017  12/17/2017  Standard Class
#
#      Customer ID    Customer Name    Segment        Country          City  \
# 2       DV-13045  Darrin Van Huff  Corporate  United States   Los Angeles
# 2976    DV-13045  Darrin Van Huff  Corporate  United States  Philadelphia
# ...

# %%
data[data['Category'] == 'Technology']
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 7          8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 11        12  CA-2014-115812    6/9/2014   6/14/2014  Standard Class
# 19        20  CA-2014-143336   8/27/2014    9/1/2014    Second Class
# 26        27  CA-2016-121755   1/16/2016   1/20/2016    Second Class
# 35        36  CA-2016-117590   12/8/2016  12/10/2016     First Class
# ...      ...             ...         ...         ...             ...
# 9983    9984  US-2016-157728   9/22/2016   9/28/2016  Standard Class
# 9986    9987  CA-2016-125794   9/29/2016   10/3/2016  Standard Class
# 9987    9988  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9988    9989  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
#
#      Customer ID       Customer Name    Segment        Country           City  \
# ...

# %%
data[(data['Category'] == 'Technology') & (data['Customer Name'] == 'Eric Hoffmann')]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 26        27  CA-2016-121755   1/16/2016   1/20/2016    Second Class
# 1110    1111  US-2016-110156  11/19/2016  11/24/2016  Standard Class
# 2732    2733  CA-2014-107594    7/2/2014    7/6/2014  Standard Class
# 6466    6467  CA-2017-153080   5/22/2017   5/25/2017    Second Class
#
#      Customer ID  Customer Name   Segment        Country         City  ...  \
# 26      EH-13945  Eric Hoffmann  Consumer  United States  Los Angeles  ...
# 1110    EH-13945  Eric Hoffmann  Consumer  United States      Houston  ...
# 2732    EH-13945  Eric Hoffmann  Consumer  United States   Plainfield  ...
# 6466    EH-13945  Eric Hoffmann  Consumer  United States  Los Angeles  ...
#
#      Postal Code   Region       Product ID    Category Sub-Category  \
# 26         90049     West  TEC-AC-10003027  Technology  Accessories
# 1110       77041  Central  TEC-PH-10003589  Technology       Phones
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.duplicated().sum()

# %%
data.info()

# %%
data.info()

# %%
data['Order Date'] = dp.to_datetime(data['Order Date'])

# %%
data['Ship Date'] = dp.to_datetime(data['Ship Date'])

# %%
data.info()

# %%
data['Order Date'] = dp.to_datetime(data['Order Date'])

# %%
data.info()

# %%
data.columns

# %%
data.columns

# %%
data['Sales'].max()

# %%
data['Sales'].min()

# %%
data.groupby('Product Name')['Sales'].sum()

# %%
data.groupby('Product Name')['Sales'].sum().max()

# %%
top_product = data.groupby('Product Name')['Sales'].sum()
top_product = top_product.sort_values(ascending=False)
top_product.head(10)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
top_product = data.groupby('Product Name')['Sales'].sum()
top_product = top_product.sort_values(ascending=False)
top_product.head(10).plot(kind='bar')
plt.title('Top 10 Products by Sales')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.show()

# %%
top_product = data.groupby('Product Name')['Sales'].sum()
top_product = top_product.sort_values(ascending=False)
top_10 = top_product.head(5)
plt.figure(figsize=(12,4))
top_10.plot(kind='bar')
plt.title('Top 10 Products by Sales')
plt.ylabel('Total Sales')
plt.xticks(rotation=90)
plt.show()

# %%
data.groupby(data['Order Date'].dt.month)['Sales'].sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data.groupby(data['Order Date'].dt.month)['Sales'].sum()
#
# File ~\OneDrive\Desktop\sales data analysis\venv\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# File ~\OneDrive\Desktop\sales data analysis\venv\Lib\site-packages\pandas\core\accessor.py:230, in Accessor.__get__(self, obj, cls)
#     227 if obj is None:
#     228     # we're accessing the attribute of the class, i.e., Dataset.geo
#     229     return self._accessor
# --> 230 return self._accessor(obj)
#
# ...
